# %%
import pandas as pd
import numpy as np

# %%
customer = pd.read_csv("C:\\Users\\maclu\\Downloads\\10. Additional Practice Exercises\\3. Pandas Case Study-1\Customers.csv",  encoding = 'unicode_escape')
customer.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %% [markdown]
# #### Q2. Understand the data using different functions and attributes like shape, index, columns, dtypes.ndim, info(), get_dtype_counts etc.m

# %%
customer.shape
# Out:
# (10000, 14)

# %%
customer.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
customer.columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %%
customer.dtypes
# Out:
# Customer_ID          int64
# Gender              object
# First_Date           int64
# First_region        object
# First_state         object
# First_city          object
# Recent_Date          int64
# Last_region         object
# Last_state          object
# Last_city           object
# Customer_Value     float64
# Buy_Times            int64
# Points_Earned      float64
# Points_Redeemed    float64
# dtype: object

# %%
customer.ndim
# Out:
# 2

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Customer_ID        10000 non-null int64
# Gender             9986 non-null object
# First_Date         10000 non-null int64
# First_region       9979 non-null object
# First_state        9983 non-null object
# First_city         10000 non-null object
# Recent_Date        10000 non-null int64
# Last_region        10000 non-null object
# Last_state         10000 non-null object
# Last_city          10000 non-null object
# Customer_Value     9964 non-null float64
# Buy_Times          10000 non-null int64
# Points_Earned      9979 non-null float64
# Points_Redeemed    9988 non-null float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
customer.get_dtype_counts
# Out:
# <bound method NDFrame.get_dtype_counts of       Customer_ID Gender  First_Date First_region     First_state  \
# 0       129609144      M    20130130         West         Gujarat
# 1       129627580      M    20130129        North           Delhi
# 2       130363481      M    20130221         West         Gujarat
# 3        49817480      M    20130222         West     Maharashtra
# 4       126343829      F    20130301        North           Delhi
# 5         8223758      F    20130314         West         Gujarat
# 6       131816709      M    20130318        South  Andhra Pradesh
# 7       118543320      F    20130321        North   Uttar Pradesh
# 8       131365512      M    20130323         East     West Bengal
# 9          758571      M    20130324        South       Karnataka
# 10       85489184      M    20120101         West     Maharashtra
# 11       85438231      M    20120103         West     Maharashtra
# 12       74053888      F    20120102         West         Gujarat
# ...

# %% [markdown]
# #### Q3. What is percentage of missing values for customer Value variable?

# %%
customer['Customer_Value'].isnull().sum()
# Out:
# 36

# %%
customer.shape[0]
# Out:
# 10000

# %%
customer['Customer_Value'].isnull().sum()/customer.shape[0]
# Out:
# 0.0036

# %%
customer['Customer_Value'].isnull().sum()/customer.shape[0]*100
# Out:
# 0.36

# %%
round(((customer['Customer_Value'].isnull().sum()/customer.shape[0])*100),3)
# Out:
# 0.36

# %% [markdown]
# #### Q4. Create two subsets with unique and duplicate values.

# %%
customer.Customer_ID.duplicated().sum()
# Out:
# 45

# %%
duplicate = customer[customer.Customer_ID.duplicated()]
duplicate.head()
# Out:
#       Customer_ID Gender  First_Date First_region  First_state First_city  \
# 9817    113918804      M    20120226         West      Gujarat  Ahmedabad
# 9818    113933467      F    20120226        South   Tamil Nadu    Chennai
# 9819     41337621      F    20120228         West      Gujarat      Surat
# 9820      6896372      M    20120228         West  Maharashtra     Nashik
# 9821    114142599      M    20120303         West      Gujarat      Surat
#
#       Recent_Date Last_region   Last_state  Last_city  Customer_Value  \
# 9817     20120712        West      Gujarat  Ahmedabad        7048.800
# 9818     20130312        East        Bihar      Patna       68863.601
# 9819     20130207        West      Gujarat      Surat        7036.001
# 9820     20120228        West  Maharashtra     Nashik        1259.000
# 9821     20130205        West      Gujarat      Surat       19136.096
#
#       Buy_Times  Points_Earned  Points_Redeemed
# 9817          6          282.0              0.0
# ...

# %%
duplicate.shape
# Out:
# (45, 14)

# %%
unique = customer[customer.Customer_ID.duplicated()==False]
unique.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
unique.shape
# Out:
# (9955, 14)

# %% [markdown]
# #### Q5. Create data set with list of customers whose customer value greater than 10000.

# %%
cust = customer[customer['Customer_Value']> 10000]
cust.shape[0]
# Out:
# 2723

# %%
cust = customer[customer['Customer_Value']> 10000].reset_index(drop = True)
cust.head()
# Out:
#    Customer_ID Gender  First_Date First_region    First_state  \
# 0      1610085      F    20120103        North          Delhi
# 1      7518872      M    20120104        North  Uttar Pradesh
# 2     63508964      M    20120106         West    Maharashtra
# 3     23667984      F    20120107         West    Maharashtra
# 4     84634600      M    20120108        South      Karnataka
#
#          First_city  Recent_Date Last_region     Last_state         Last_city  \
# 0             Delhi     20121013       North          Delhi             Delhi
# 1            Kanpur     20130123       North  Uttar Pradesh            Kanpur
# 2  Pimpri-Chinchwad     20130222        West    Maharashtra  Pimpri-Chinchwad
# 3            Nagpur     20130313        West    Maharashtra            Nagpur
# 4         Bangalore     20130307       South      Karnataka         Bangalore
#
#    Customer_Value  Buy_Times  Points_Earned  Points_Redeemed
# 0       10380.199          6         1189.0              0.0
# ...

# %% [markdown]
# #### 6. In customer table, create a new variable called “customer value segment” using customer value as follows.

# %% [markdown]
# High Segment - > 25000.
# Medium Segment – Between 10000 and 25000
# Low Segment – less than or equal to 10000

# %%
from numpy import where as IF

# %%
# C = customer_value
C = customer.Customer_Value
customer['Customer_value_segment']= IF(C > 25000, 'HIgh Segment', IF((C > 10000) & (C < 25000),'Medium Segment','Low Segment'))
customer.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
# ...

# %% [markdown]
# #### 7. Create variables “average revenue per trip” and “balance points” in the customer data set.

# %%
customer = customer.assign(average_revenue_per_trip= customer.Customer_Value/customer.Buy_Times,
                  Balance_Points=customer.Points_Earned - customer.Points_Redeemed )
customer.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
# ...

# %% [markdown]
# #### 8. How many days between last purchase date and today?

# %%
import datetime as dt
today = pd.to_datetime(dt.datetime.now().date())
day = today - pd.to_datetime(customer.Recent_Date,format= '%Y%m%d')
day
# Out:
# 0      2858 days
# 1      2876 days
# 2      2853 days
# 3      2852 days
# 4      2845 days
# 5      2832 days
# 6      2828 days
# 7      2825 days
# 8      2815 days
# 9      2821 days
# 10     3270 days
# 11     2955 days
# 12     2832 days
# 13     2940 days
# 14     2984 days
# 15     2882 days
# 16     3268 days
# 17     2862 days
# 18     2852 days
# 19     2833 days
# 20     2839 days
# 21     2907 days
# 22     3260 days
# 23     2926 days
# 24     2844 days
# 25     3260 days
# 26     3096 days
# 27     2887 days
# 28     2852 days
# 29     2897 days
#           ...
# 9970   2816 days
# 9971   2852 days
# 9972   2983 days
# 9973   2852 days
# 9974   2827 days
# 9975   3126 days
# 9976   2891 days
# 9977   3250 days
# 9978   3244 days
# 9979   2939 days
# 9980   2834 days
# 9981   3240 days
# 9982   2833 days
# 9983   2836 days
# 9984   2836 days
# 9985   2925 days
# 9986   3239 days
# 9987   2818 days
# 9988   3239 days
# 9989   3239 days
# 9990   3237 days
# ...

# %% [markdown]
# #### 9. Calculate percentage of sales by each last city, state and region.

# %%
demography= customer[['Last_region', 'Last_state', 'Last_city', 'Customer_Value']]
demography.head()
# Out:
#   Last_region   Last_state         Last_city  Customer_Value
# 0        West      Gujarat             Surat          2032.0
# 1       North        Delhi             Delhi          1709.0
# 2        West      Gujarat             Surat           523.0
# 3        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4       North        Delhi             Delhi          1008.0

# %%
demography.groupby(['Last_region'])['Customer_Value'].sum()/demography.Customer_Value.sum()
# Out:
# Last_region
# East     0.077987
# North    0.277416
# South    0.154038
# West     0.490560
# Name: Customer_Value, dtype: float64

# %%
demography.groupby(['Last_region', 'Last_state'])['Customer_Value'].sum()/demography.Customer_Value.sum()
# Out:
# Last_region  Last_state
# East         Assam                0.015573
#              Bihar                0.002606
#              Jharkhand            0.002456
#              Tripura              0.000188
#              West Bengal          0.057162
# North        Chandigarh           0.000328
#              Chhattisgarh         0.000053
#              Delhi                0.085912
#              Haryana              0.001415
#              Jammu and Kashmir    0.000049
#              Madhya Pradesh       0.053475
#              Orissa               0.001566
#              Punjab               0.000088
#              Rajasthan            0.031332
#              Uttar Pradesh        0.102959
#              Uttarakhand          0.000238
# South        Andhra Pradesh       0.014727
#              Karnataka            0.053301
#              Kerala               0.001009
#              Puducherry           0.000224
#              Tamil Nadu           0.046566
# ...

# %%
demography.groupby(['Last_region', 'Last_state', 'Last_city'])['Customer_Value'].sum()/demography.Customer_Value.sum()
# Out:
# Last_region  Last_state         Last_city
# East         Assam              Guwahati            0.015573
#              Bihar              Begusarai           0.000206
#                                 Bhagalpur           0.000022
#                                 Katihar             0.000469
#                                 Patna               0.001851
#                                 Purnia              0.000059
#              Jharkhand          Dhanbad             0.001975
#                                 Jamshedpur          0.000028
#                                 Ranchi              0.000453
#              Tripura            Agartala            0.000188
#              West Bengal        Asansol             0.000030
#                                 Baranagar           0.000160
#                                 Barasat             0.000040
#                                 Bhatpara            0.000635
#                                 Howrah              0.000178
# ...

# %% [markdown]
# #### 10. What is the count of customers, average number of purchases and average purchase transaction value by last state and city.

# %%
customer.groupby(['Last_state', 'Last_city'])['Customer_ID'].count()
# Out:
# Last_state         Last_city
# Andhra Pradesh     Guntur                1
#                    Kurnool               1
#                    Tirupati              2
#                    Vijayawada           20
#                    Visakhapatnam       117
#                    Vizianagaram          1
# Assam              Guwahati             30
# Bihar              Begusarai             1
#                    Bhagalpur             1
#                    Katihar               2
#                    Patna                20
#                    Purnia                1
# Chandigarh         Chandigarh            6
# Chhattisgarh       Korba                 1
#                    Raipur                1
# Delhi              Delhi              1034
#                    Karawal Nagar         2
#                    New Delhi             1
# Gujarat            Ahmedabad           621
#                    Gandhidham            1
#                    Jamnagar              6
# ...

# %%
customer.groupby(['Last_state', 'Last_city'])['Buy_Times'].count()
# Out:
# Last_state         Last_city
# Andhra Pradesh     Guntur                1
#                    Kurnool               1
#                    Tirupati              2
#                    Vijayawada           20
#                    Visakhapatnam       117
#                    Vizianagaram          1
# Assam              Guwahati             30
# Bihar              Begusarai             1
#                    Bhagalpur             1
#                    Katihar               2
#                    Patna                20
#                    Purnia                1
# Chandigarh         Chandigarh            6
# Chhattisgarh       Korba                 1
#                    Raipur                1
# Delhi              Delhi              1034
#                    Karawal Nagar         2
#                    New Delhi             1
# Gujarat            Ahmedabad           621
#                    Gandhidham            1
#                    Jamnagar              6
# ...

# %%
customer.groupby(['Last_state', 'Last_city'])['average_revenue_per_trip'].mean()
# Out:
# Last_state         Last_city
# Andhra Pradesh     Guntur                0.000000
#                    Kurnool             778.374750
#                    Tirupati           1828.333333
#                    Vijayawada         1981.191171
#                    Visakhapatnam      2383.914601
#                    Vizianagaram       1920.216667
# Assam              Guwahati           1454.017522
# Bihar              Begusarai          2855.333222
#                    Bhagalpur           929.266333
#                    Katihar            1847.899976
#                    Patna              1475.133293
#                    Purnia             1833.500000
# Chandigarh         Chandigarh         2014.771241
# Chhattisgarh       Korba               928.800000
#                    Raipur             1288.666667
# Delhi              Delhi              2125.372904
#                    Karawal Nagar      1189.716667
#                    New Delhi           886.666667
# ...
